# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../data/raw/brain_tumor_data.csv')

# %%
df.describe()
# Out:
#                age          bmi  tumor_size_mm  tumor_growth_rate  \
# count  9000.000000  8564.000000    9000.000000        8460.000000
# mean     55.740778    25.966604      31.072267           5.167163
# std      14.665020     4.482363      17.435163           3.666994
# min       5.000000    14.000000       2.000000           0.100000
# 25%      47.000000    23.000000      17.600000           2.320000
# 50%      57.000000    26.000000      28.600000           4.100000
# 75%      66.000000    29.000000      41.500000           7.812500
# max      95.000000    44.800000      90.000000          19.630000
#
#        headache_severity  mri_intensity   ct_density  edema_grade  \
# count        8543.000000    8644.000000  8566.000000  8717.000000
# mean            5.019782     160.225659    40.083294     1.259837
# std             2.447713      36.636825    17.876407     1.062550
# min             0.000000      37.500000   -48.700000     0.000000
# ...
