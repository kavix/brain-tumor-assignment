# %%
import pandas as pd
import numpy as np

# Set random seed for reproducibility
RANDOM_SEED = 42
np.random.seed(RANDOM_SEED)

# Load data
df = pd.read_csv('../data/raw/brain_tumor_data.csv')

# Report shape, dtypes, first rows
print(f"Shape: {df.shape}")  # Expected: (9000, 28) - 27 features + target
print(df.dtypes)
print(df.head(10))
